# %% [markdown]
# # Practical 12

# %%
print(5)
# Out:
# 5

# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df.sample(7)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 807   54   M           ATA        108          309          0     Normal
# 123   58   F           ATA        180          393          0     Normal
# 137   39   M           ATA        120          241          0         ST
# 218   55   M           ATA        140          196          0     Normal
# 180   52   M           ASY        130          225          0     Normal
# 243   43   F           ATA        120          266          0     Normal
# 189   53   M           ASY        180          285          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 807    156              N      0.0       Up             0
# 123    110              Y      1.0     Flat             1
# 137    146              N      2.0       Up             0
# 218    150              N      0.0       Up             0
# 180    120              Y      2.0     Flat             1
# ...
